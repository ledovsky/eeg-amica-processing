# %% [markdown]
# ## An example of the processed data

# %%
from os.path import join
import mne

# %%
data_path = input()

# %%
ica = mne.preprocessing.read_ica(join(data_path, 'postprocessed', 'matrix_eeg_stack01_amica_ica.fif'))
# Out:
# Reading ../kids_amica_data/postprocessed/matrix_eeg_stack01_amica_ica.fif ...
# Now restoring ICA solution ...
# Ready.

# %%
ica.plot_components()
# Out:
# <MNEFigure size 975x967 with 20 Axes>
# <MNEFigure size 975x731.5 with 11 Axes>
# [<MNEFigure size 975x967 with 20 Axes>,
#  <MNEFigure size 975x731.5 with 11 Axes>]
